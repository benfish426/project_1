# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

csv_path = Path("../test/car_price.csv")
cars_df = pd.read_csv(csv_path)

cars_df.head(100)
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 0        1          3        alfa-romero giulia      gas        std
# 1        2          3       alfa-romero stelvio      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 3        4          2               audi 100 ls      gas        std
# 4        5          2                audi 100ls      gas        std
# ..     ...        ...                       ...      ...        ...
# 95      96          1               nissan juke      gas        std
# 96      97          1              nissan latio      gas        std
# 97      98          1               nissan note      gas        std
# 98      99          2            nissan clipper      gas        std
# 99     100          0              nissan rogue      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0         two  convertible        rwd          front       88.6  ...
# ...

# %%
pd.options.display.max_rows = 999

# %%
csv_path = Path("../test/car_price.csv")
cars_df = pd.read_csv(csv_path)

cars_df.head(100)
# Out:
#     car_ID  symboling                          CarName fueltype aspiration  \
# 0        1          3               alfa-romero giulia      gas        std
# 1        2          3              alfa-romero stelvio      gas        std
# 2        3          1         alfa-romero Quadrifoglio      gas        std
# 3        4          2                      audi 100 ls      gas        std
# 4        5          2                       audi 100ls      gas        std
# 5        6          2                         audi fox      gas        std
# 6        7          1                       audi 100ls      gas        std
# 7        8          1                        audi 5000      gas        std
# 8        9          1                        audi 4000      gas      turbo
# 9       10          0              audi 5000s (diesel)      gas      turbo
# 10      11          2                         bmw 320i      gas        std
# ...

# %%
cars_df = cars_df.set_index("car_ID")
cars_df
# Out:
#         symboling                          CarName fueltype aspiration  \
# car_ID
# 1               3               alfa-romero giulia      gas        std
# 2               3              alfa-romero stelvio      gas        std
# 3               1         alfa-romero Quadrifoglio      gas        std
# 4               2                      audi 100 ls      gas        std
# 5               2                       audi 100ls      gas        std
# 6               2                         audi fox      gas        std
# 7               1                       audi 100ls      gas        std
# 8               1                        audi 5000      gas        std
# 9               1                        audi 4000      gas      turbo
# 10              0              audi 5000s (diesel)      gas      turbo
# 11              2                         bmw 320i      gas        std
# 12              0                         bmw 320i      gas        std
# ...

# %%
cars_df = cars_df.drop(columns="symboling")
cars_df
# Out:
#                                 CarName fueltype aspiration doornumber  \
# car_ID
# 1                    alfa-romero giulia      gas        std        two
# 2                   alfa-romero stelvio      gas        std        two
# 3              alfa-romero Quadrifoglio      gas        std        two
# 4                           audi 100 ls      gas        std       four
# 5                            audi 100ls      gas        std       four
# 6                              audi fox      gas        std        two
# 7                            audi 100ls      gas        std       four
# 8                             audi 5000      gas        std       four
# 9                             audi 4000      gas      turbo       four
# 10                  audi 5000s (diesel)      gas      turbo        two
# 11                             bmw 320i      gas        std        two
# 12                             bmw 320i      gas        std       four
# ...

# %%
cars_df[['Car Make', 'Car Model']] = cars_df['CarName'].str.split(pat=" ", n=1, expand=True)
cars_df
# Out:
#                                 CarName fueltype aspiration doornumber  \
# car_ID
# 1                    alfa-romero giulia      gas        std        two
# 2                   alfa-romero stelvio      gas        std        two
# 3              alfa-romero Quadrifoglio      gas        std        two
# 4                           audi 100 ls      gas        std       four
# 5                            audi 100ls      gas        std       four
# 6                              audi fox      gas        std        two
# 7                            audi 100ls      gas        std       four
# 8                             audi 5000      gas        std       four
# 9                             audi 4000      gas      turbo       four
# 10                  audi 5000s (diesel)      gas      turbo        two
# 11                             bmw 320i      gas        std        two
# 12                             bmw 320i      gas        std       four
# ...

# %%
cars_df.columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price', 'Car Make', 'Car Model'],
#       dtype='object')

# %%
cars_df[["Car Make", "Car Model","fueltype", "aspiration", "doornumber", "carbody",
       "drivewheel", "enginelocation", "wheelbase", "carlength", "carwidth",
       "carheight", "curbweight", "enginetype", "cylindernumber", "enginesize",
       "fuelsystem", "boreratio", "stroke", "compressionratio", "horsepower",
       "peakrpm", "citympg", "highwaympg", "price"]]

cars_df
# Out:
#                                 CarName fueltype aspiration doornumber  \
# car_ID
# 1                    alfa-romero giulia      gas        std        two
# 2                   alfa-romero stelvio      gas        std        two
# 3              alfa-romero Quadrifoglio      gas        std        two
# 4                           audi 100 ls      gas        std       four
# 5                            audi 100ls      gas        std       four
# 6                              audi fox      gas        std        two
# 7                            audi 100ls      gas        std       four
# 8                             audi 5000      gas        std       four
# 9                             audi 4000      gas      turbo       four
# 10                  audi 5000s (diesel)      gas      turbo        two
# 11                             bmw 320i      gas        std        two
# 12                             bmw 320i      gas        std       four
# ...

# %%
cars_df = cars_df.rename(columns={"Car_Make":" Car Make", "Car_Model":"Car Model","fueltype":"Fuel Type", 
                                  "aspiration": "Aspiration", "doornumber":"Number of Doors", "carbody":"Body Type", 
                                  "drivewheel":"Drivetrain", "enginelocation":"Location of Engine", "wheelbase":"Wheelbase",
                                  "carlength":"Length of Car", "carwidth":"Width of Car", "carheight":"Height of Car", 
                                  "curbweight":"Curb Weight", "enginetype":"Engine Type", "cylindernumber":"Number of Cylinders",
                                  "enginesize":"Engine Size", "fuelsystem":"Fuel System", "boreratio":"Bore Ratio", 
                                  "stroke":"Stroke", "compressionratio":"Compression Ratio", "horsepower":"Horsepower", 
                                  "peakrpm":"Peak RPM", "citympg":"City MPG", "highwaympg":"Highway MPG", "price":"Price"})

cars_df
# Out:
#                                 CarName Fuel Type Aspiration Number of Doors  \
# car_ID
# 1                    alfa-romero giulia       gas        std             two
# 2                   alfa-romero stelvio       gas        std             two
# 3              alfa-romero Quadrifoglio       gas        std             two
# 4                           audi 100 ls       gas        std            four
# 5                            audi 100ls       gas        std            four
# 6                              audi fox       gas        std             two
# 7                            audi 100ls       gas        std            four
# 8                             audi 5000       gas        std            four
# 9                             audi 4000       gas      turbo            four
# 10                  audi 5000s (diesel)       gas      turbo             two
# 11                             bmw 320i       gas        std             two
# ...

# %%
cars_df.columns
# Out:
# Index(['CarName', 'Fuel Type', 'Aspiration', 'Number of Doors', 'Body Type',
#        'Drivetrain', 'Location of Engine', 'Wheelbase', 'Length of Car',
#        'Width of Car', 'Height of Car', 'Curb Weight', 'Engine Type',
#        'Number of Cylinders', 'Engine Size', 'Fuel System', 'Bore Ratio',
#        'Stroke', 'Compression Ratio', 'Horsepower', 'Peak RPM', 'City MPG',
#        'Highway MPG', 'Price', 'Car Make', 'Car Model'],
#       dtype='object')

# %%
cars_df = cars_df.loc[:, ['CarName', "Car Make", 'Car Model','Fuel Type', 'Aspiration', 'Number of Doors', 'Body Type',
                          'Drivetrain', 'Location of Engine', 'Wheelbase', 'Length of Car',
                          'Width of Car', 'Height of Car', 'Curb Weight', 'Engine Type',
                          'Number of Cylinders', 'Engine Size', 'Fuel System', 'Bore Ratio',
                          'Stroke', 'Compression Ratio', 'Horsepower', 'Peak RPM', 'City MPG',
                          'Highway MPG', 'Price']]

cars_df
# Out:
#                                 CarName     Car Make  \
# car_ID
# 1                    alfa-romero giulia  alfa-romero
# 2                   alfa-romero stelvio  alfa-romero
# 3              alfa-romero Quadrifoglio  alfa-romero
# 4                           audi 100 ls         audi
# 5                            audi 100ls         audi
# 6                              audi fox         audi
# 7                            audi 100ls         audi
# 8                             audi 5000         audi
# 9                             audi 4000         audi
# 10                  audi 5000s (diesel)         audi
# 11                             bmw 320i          bmw
# 12                             bmw 320i          bmw
# 13                               bmw x1          bmw
# 14                               bmw x3          bmw
# 15                               bmw z4          bmw
# 16                               bmw x4          bmw
# ...

# %%
cars_df = cars_df.drop(columns="CarName")
cars_df
# Out:
#            Car Make                  Car Model Fuel Type Aspiration  \
# car_ID
# 1       alfa-romero                     giulia       gas        std
# 2       alfa-romero                    stelvio       gas        std
# 3       alfa-romero               Quadrifoglio       gas        std
# 4              audi                     100 ls       gas        std
# 5              audi                      100ls       gas        std
# 6              audi                        fox       gas        std
# 7              audi                      100ls       gas        std
# 8              audi                       5000       gas        std
# 9              audi                       4000       gas      turbo
# 10             audi             5000s (diesel)       gas      turbo
# 11              bmw                       320i       gas        std
# 12              bmw                       320i       gas        std
# 13              bmw                         x1       gas        std
# ...

# %%
x = cars_df.loc[:,"City MPG"].values
y = cars_df.loc[:,"Highway MPG"].values

cars_df["Average MPG"] = (x + y) / 2
cars_df
# Out:
#            Car Make                  Car Model Fuel Type Aspiration  \
# car_ID
# 1       alfa-romero                     giulia       gas        std
# 2       alfa-romero                    stelvio       gas        std
# 3       alfa-romero               Quadrifoglio       gas        std
# 4              audi                     100 ls       gas        std
# 5              audi                      100ls       gas        std
# 6              audi                        fox       gas        std
# 7              audi                      100ls       gas        std
# 8              audi                       5000       gas        std
# 9              audi                       4000       gas      turbo
# 10             audi             5000s (diesel)       gas      turbo
# 11              bmw                       320i       gas        std
# 12              bmw                       320i       gas        std
# 13              bmw                         x1       gas        std
# ...

# %%
cars_df = cars_df.loc[:, ["Car Make", 'Car Model','Fuel Type', 'Aspiration', 'Number of Doors', 'Body Type',
                          'Drivetrain', 'Location of Engine', 'Wheelbase', 'Length of Car',
                          'Width of Car', 'Height of Car', 'Curb Weight', 'Engine Type',
                          'Number of Cylinders', 'Engine Size', 'Fuel System', 'Bore Ratio',
                          'Stroke', 'Compression Ratio', 'Horsepower', 'Peak RPM', 'City MPG',
                          'Highway MPG', "Average MPG",'Price']]

cars_df
# Out:
#            Car Make                  Car Model Fuel Type Aspiration  \
# car_ID
# 1       alfa-romero                     giulia       gas        std
# 2       alfa-romero                    stelvio       gas        std
# 3       alfa-romero               Quadrifoglio       gas        std
# 4              audi                     100 ls       gas        std
# 5              audi                      100ls       gas        std
# 6              audi                        fox       gas        std
# 7              audi                      100ls       gas        std
# 8              audi                       5000       gas        std
# 9              audi                       4000       gas      turbo
# 10             audi             5000s (diesel)       gas      turbo
# 11              bmw                       320i       gas        std
# 12              bmw                       320i       gas        std
# 13              bmw                         x1       gas        std
# ...
